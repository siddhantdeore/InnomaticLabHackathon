# %% [markdown]
# <a href="https://colab.research.google.com/github/siddhantdeore/InnomaticLabHackathon/blob/main/Task_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Employee Performance Bonus Eligibility

employees = {
    "Ravi": 92,
    "Anita": 88,
    "Kiran": 92,
    "Suresh": 85
}

# find highest score
highest_score = max(employees.values())

# find all employees with highest score
top_performers = []

for name, score in employees.items():
    if score == highest_score:
        top_performers.append(name)

# output
print("Top Performers Eligible for Bonus:",
      ", ".join(top_performers),
      f"(Score: {highest_score})")
# Out:
# Top Performers Eligible for Bonus: Ravi, Kiran (Score: 92)

# %%
# Search Query Keyword Analysis

query = "Buy mobile phone buy phone online"

# convert to lowercase
query = query.lower()

# remove punctuation (basic)
import string
for p in string.punctuation:
    query = query.replace(p, "")

# split into words
words = query.split()

# count frequency
freq = {}
for w in words:
    if w in freq:
        freq[w] += 1
    else:
        freq[w] = 1

# keep only keywords searched more than once
result = {}
for k, v in freq.items():
    if v > 1:
        result[k] = v

print(result)
# Out:
# {'buy': 2, 'phone': 2}

# %%
# Sensor Data Validation

sensor_readings = [3, 4, 7, 8, 10, 12, 5]

valid_readings = []

for index, value in enumerate(sensor_readings):
    if value % 2 == 0:          # even = valid
        valid_readings.append((index, value))

print("Valid Sensor Readings (Hour, Value):")
print(valid_readings)
# Out:
# Valid Sensor Readings (Hour, Value):
# [(1, 4), (3, 8), (4, 10), (5, 12)]

# %%
# Email Domain Usage Analysis

emails = [
    "ravi@gmail.com",
    "anita@yahoo.com",
    "kiran@gmail.com",
    "suresh@gmail.com",
    "meena@yahoo.com"
]

domain_count = {}

# count domains
for email in emails:
    domain = email.split("@")[1]
    if domain in domain_count:
        domain_count[domain] += 1
    else:
        domain_count[domain] = 1

total_users = len(emails)

# calculate percentage
for domain, count in domain_count.items():
    percentage = (count / total_users) * 100
    print(f"{domain}: {percentage:.0f}%")
# Out:
# gmail.com: 60%
# yahoo.com: 40%

# %%
# Sales Spike Detection

sales = [1200, 1500, 900, 2200, 1400, 3000]

# calculate average sales
average_sales = sum(sales) / len(sales)

# threshold = 30% above average
threshold = average_sales * 1.30

# detect spikes
for day, value in enumerate(sales, start=1):
    if value > threshold:
        print(f"Day {day}: {value}")
# Out:
# Day 6: 3000

# %%
# Duplicate User ID Detection

user_ids = ["user1", "user2", "user1", "user3", "user1", "user3"]

count_dict = {}

# count occurrences
for uid in user_ids:
    if uid in count_dict:
        count_dict[uid] += 1
    else:
        count_dict[uid] = 1

# display only duplicates
for uid, count in count_dict.items():
    if count > 1:
        print(f"{uid} → {count} times")
# Out:
# user1 → 3 times
# user3 → 2 times
