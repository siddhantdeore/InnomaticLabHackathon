# %% [markdown]
# <a href="https://colab.research.google.com/github/siddhantdeore/InnomaticLabHackathon/blob/main/Innomatics_Labs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import json
import sqlite3

# %%
orders = pd.read_csv("orders.csv")

with open("users.json", "r") as f:
    users = pd.DataFrame(json.load(f))

conn = sqlite3.connect(":memory:")
with open("restaurants.sql", "r") as f:
    conn.executescript(f.read())

restaurants = pd.read_sql("SELECT * FROM restaurants", conn)

# %%
df = orders.merge(users, on="user_id", how="left")

df = df.merge(restaurants, on="restaurant_id", how="left")

df.head()
# Out:
#    order_id  user_id  restaurant_id  order_date  total_amount  \
# 0         1     2508            450  18-02-2023        842.97
# 1         2     2693            309  18-01-2023        546.68
# 2         3     2084            107  15-07-2023        163.93
# 3         4      319            224  04-10-2023       1155.97
# 4         5     1064            293  25-12-2023       1321.91
#
#                 restaurant_name_x       name       city membership  \
# 0               New Foods Chinese  User_2508  Hyderabad    Regular
# 1  Ruchi Curry House Multicuisine  User_2693       Pune    Regular
# 2           Spice Kitchen Punjabi  User_2084    Chennai       Gold
# 3          Darbar Kitchen Non-Veg   User_319  Bangalore       Gold
# 4       Royal Eatery South Indian  User_1064       Pune    Regular
#
#   restaurant_name_y  cuisine  rating
# 0    Restaurant_450  Mexican     3.2
# 1    Restaurant_309   Indian     4.5
# 2    Restaurant_107  Mexican     4.0
# 3    Restaurant_224  Chinese     4.8
# 4    Restaurant_293  Italian     3.0

# %%
df.to_csv("combined_data.csv", index=False)

# %%
df[df["membership"] == "Gold"] \
  .groupby("city")["total_amount"] \
  .sum() \
  .sort_values(ascending=False)
# Out:
# city
# Chennai      1080909.79
# Pune         1003012.32
# Bangalore     994702.59
# Hyderabad     896740.19
# Name: total_amount, dtype: float64

# %%
df.groupby("cuisine")["total_amount"] \
  .mean() \
  .sort_values(ascending=False)
# Out:
# cuisine
# Mexican    808.021344
# Italian    799.448578
# Indian     798.466011
# Chinese    798.389020
# Name: total_amount, dtype: float64

# %%
(df.groupby("user_id")["total_amount"].sum() > 1000).sum()
# Out:
# np.int64(2544)

# %%
bins = [0, 3.5, 4.0, 4.5, 5.0]
labels = ["<3.5", "3.5–4.0", "4.0–4.5", "4.5–5.0"]

df["rating_range"] = pd.cut(df["rating"], bins=bins, labels=labels)

df.groupby("rating_range")["total_amount"] \
  .sum() \
  .sort_values(ascending=False)
# Out:
# /tmp/ipython-input-2535514227.py:6: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("rating_range")["total_amount"] \
# rating_range
# 4.5–5.0    2197030.75
# <3.5       2136772.70
# 4.0–4.5    1960326.26
# 3.5–4.0    1717494.41
# Name: total_amount, dtype: float64

# %%
df[df["membership"] == "Gold"] \
  .groupby("city")["total_amount"] \
  .mean() \
  .sort_values(ascending=False)
# Out:
# city
# Chennai      808.459080
# Hyderabad    806.421034
# Bangalore    793.223756
# Pune         781.162243
# Name: total_amount, dtype: float64

# %%
df.groupby("cuisine").agg(
    distinct_restaurants=("restaurant_id", "nunique"),
    total_revenue=("total_amount", "sum")
).sort_values("distinct_restaurants")
# Out:
#          distinct_restaurants  total_revenue
# cuisine
# Chinese                   120     1930504.65
# Indian                    126     1971412.58
# Italian                   126     2024203.80
# Mexican                   128     2085503.09

# %%
round(
    (df[df["membership"] == "Gold"].shape[0] / df.shape[0]) * 100
)
# Out:
# 50

# %%
df.groupby("restaurant_name_x").agg(
    order_count=("order_id", "count"),
    avg_order_value=("total_amount", "mean")
).query("order_count < 20") \
 .sort_values("avg_order_value", ascending=False) \
 .head(1)
# Out:
#                           order_count  avg_order_value
# restaurant_name_x
# Hotel Dhaba Multicuisine           13      1040.222308

# %%
df.groupby(["membership","cuisine"])["total_amount"] \
  .sum() \
  .sort_values(ascending=False)
# Out:
# membership  cuisine
# Regular     Mexican    1072943.30
#             Italian    1018424.75
# Gold        Mexican    1012559.79
#             Italian    1005779.05
# Regular     Indian      992100.27
# Gold        Indian      979312.31
#             Chinese     977713.74
# Regular     Chinese     952790.91
# Name: total_amount, dtype: float64

# %%
df["order_date"] = pd.to_datetime(df["order_date"], dayfirst=True)
df["quarter"] = df["order_date"].dt.to_period("Q")

df.groupby("quarter")["total_amount"] \
  .sum() \
  .sort_values(ascending=False)
# Out:
# quarter
# 2023Q3    2037385.10
# 2023Q4    2018263.66
# 2023Q1    1993425.14
# 2023Q2    1945348.72
# 2024Q1      17201.50
# Freq: Q-DEC, Name: total_amount, dtype: float64

# %%
df[df["membership"] == "Gold"].shape[0]
# Out:
# 4987

# %%
round(df[df["city"] == "Hyderabad"]["total_amount"].sum())
# Out:
# 1889367

# %%
df["user_id"].nunique()
# Out:
# 2883

# %%
round(
    df[df["membership"] == "Gold"]["total_amount"].mean(),
    2
)
# Out:
# np.float64(797.15)

# %%
orders_high_rating = df[df["rating"] >= 4.5].shape[0]

gold = df[df["membership"] == "Gold"]
top_city = gold.groupby("city")["total_amount"].sum().idxmax()

orders_top_city_gold = gold[gold["city"] == top_city].shape[0]

orders_high_rating, top_city, orders_top_city_gold
# Out:
# (3374, 'Chennai', 1337)

# %%
set(orders.columns).intersection(set(users.columns))
# Out:
# {'user_id'}

# %%
df.shape[0]
# Out:
# 10000

# %%
df[df["name"].isna()].head()
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, restaurant_id, order_date, total_amount, restaurant_name_x, name, city, membership, restaurant_name_y, cuisine, rating, rating_range, quarter]
# Index: []

# %%
users.columns
# Out:
# Index(['user_id', 'name', 'city', 'membership'], dtype='object')

# %%
restaurants["cuisine"].unique()
# Out:
# array(['Chinese', 'Indian', 'Mexican', 'Italian'], dtype=object)

# %%
df["user_id"].value_counts().head()
# Out:
# user_id
# 2973    13
# 1515    12
# 874     11
# 496     11
# 1337    11
# Name: count, dtype: int64
